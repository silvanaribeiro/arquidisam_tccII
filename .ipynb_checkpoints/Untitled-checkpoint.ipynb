# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
text = "hello there you little beautiful dogs!"

# %%
# %timeit print(text)
# Out:
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# hello there you little beautiful dogs!
# ...

# %%
sum(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-0e988d375959> in <module>()
# ----> 1 sum(text)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
# > <ipython-input-4-0e988d375959>(1)<module>()
# ----> 1 sum(text)
#
# ipdb> text
# 'hello there you little beautiful dogs!'

# %%
import unicodecsv
with open('c:/users/silva/documents/udacity\ -\ data\ analysis/enrollments.csv') as csvFile:
    reader = unicodecsv.DictReader(csvFile)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c7614f64ada2> in <module>()
#       1 import unicodecsv
# ----> 2 with open('c:/users/silva/documents/udacity - data analysis/enrollments.csv') as csvFile:
#       3     reader = unicodecsv.DictReader(csvFile)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:/users/silva/documents/udacity - data analysis/enrollments.csv'
